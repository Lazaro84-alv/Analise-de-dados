# %%
import pandas as pd

# %%
df1 = pd.read_excel("Aracaju.xlsx")
df2 = pd.read_excel("Fortaleza.xlsx")
df3 = pd.read_excel("Natal.xlsx")
df4 = pd.read_excel("Recife.xlsx")
df5 = pd.read_excel("Salvador.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-681f3d492247> in <module>()
# ----> 1 df1 = pd.read_excel("Aracaju.xlsx")
#       2 df2 = pd.read_excel("Fortaleza.xlsx")
#       3 df3 = pd.read_excel("Natal.xlsx")
#       4 df4 = pd.read_excel("Recife.xlsx")
#       5 df5 = pd.read_excel("Salvador.xlsx")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_xlrd.py in load_workbook(self, filepath_or_buffer)
#      35             return open_workbook(file_contents=data)
#      36         else:
# ---> 37             return open_workbook(filepath_or_buffer)
#      38
#      39     @property
#
# /usr/local/lib/python3.7/dist-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     114         peek = file_contents[:peeksz]
#     115     else:
# --> 116         with open(filename, "rb") as f:
#     117             peek = f.read(peeksz)
#     118     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Aracaju.xlsx'

# %%
df1.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df["Vendas"].fillna(df["Vendas"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df["Vendas"].fillna(0, inplace=True)

# %%
df.dropna(0, inplace=True)

# %%
df.sample(15)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde
# 105      Natal 2019-01-02   32.83   1037     1
# 14   Fortaleza 2019-01-12  132.68   1005     1
# 97    Salvador 2019-01-01   39.91   1037     3
# 147      Natal 2019-01-02   34.50   1035     1
# 70      Recife 2019-01-01   20.40    983     7
# 179   Salvador 2019-01-02   64.95   1036     1
# 232      Natal 2019-01-03  167.76   1034     3
# 130   Salvador 2019-03-02   59.78   1036     1
# 160   Salvador 2019-01-02   11.76   1034     1
# 47      Recife 2019-01-01    8.60    983     3
# 0      Aracaju 2018-01-01  142.00   1520     1
# 197      Natal 2019-01-02   10.45   1036     2
# 184      Natal 2019-01-02  167.16   1037     1
# 87   Fortaleza 2019-01-01   42.04   1002     5
# 77   Fortaleza 2019-01-01  167.64   1005     1

# %%
df["Vendas"].mean()
# Out:
# 122.61180089485438

# %%
df.dropna(subset=["Vendas"], inplace=True)

# %%
df.dropna(how="all", inplace=True)

# %%
df["Receitas"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde  Receitas
# 0  Aracaju 2018-01-01  142.00    1520     1    142.00
# 1  Aracaju 2018-01-01   14.21    1522     6     85.26
# 2  Aracaju 2018-01-01   71.55    1520     1     71.55
# 3  Aracaju 2018-01-01    3.01    1521     7     21.07
# 4  Aracaju 2018-01-01   24.51    1522     8    196.08

# %%
df["Receitas/Vendas"] = df["Receitas"] / df["Vendas"]

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde  Receitas  Receitas/Vendas
# 0  Aracaju 2018-01-01  142.00    1520     1    142.00              1.0
# 1  Aracaju 2018-01-01   14.21    1522     6     85.26              6.0
# 2  Aracaju 2018-01-01   71.55    1520     1     71.55              1.0
# 3  Aracaju 2018-01-01    3.01    1521     7     21.07              7.0
# 4  Aracaju 2018-01-01   24.51    1522     8    196.08              8.0

# %%
df["Receitas"].max()
# Out:
# 3544.0

# %%
df["Receitas"].min()
# Out:
# 3.34

# %%
df.nlargest(3, "Receitas")
# Out:
#    Cidade       Data  Vendas  LojaID  Qtde  Receitas  Receitas/Vendas
# 7   Natal 2019-03-18   886.0     853     4    3544.0              4.0
# 51  Natal 2018-01-21   859.0     852     4    3436.0              4.0
# 55  Natal 2019-01-08   859.0     854     4    3436.0              4.0

# %%
df.nsmallest(3, "Receitas")
# Out:
#       Cidade       Data  Vendas  LojaID  Qtde  Receitas  Receitas/Vendas
# 118  Aracaju 2018-01-01    3.34    1522     1      3.34              1.0
# 65    Recife 2019-01-01    4.01     981     1      4.01              1.0
# 92     Natal 2019-01-02    4.57    1035     1      4.57              1.0

# %%
df.groupby("Cidade")["Receitas"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receitas, dtype: float64

# %%
df.sort_values("Receitas", ascending=False).head(10)
# Out:
#    Cidade       Data  Vendas  LojaID  Qtde  Receitas  Receitas/Vendas
# 7   Natal 2019-03-18   886.0     853     4    3544.0              4.0
# 55  Natal 2019-01-08   859.0     854     4    3436.0              4.0
# 51  Natal 2018-01-21   859.0     852     4    3436.0              4.0
# 30  Natal 2018-10-02   856.0     853     4    3424.0              4.0
# 41  Natal 2018-05-20   835.0     852     4    3340.0              4.0
# 38  Natal 2018-02-25   828.0     852     4    3312.0              4.0
# 10  Natal 2018-10-27   828.0     852     4    3312.0              4.0
# 69  Natal 2019-03-24   817.0     852     4    3268.0              4.0
# 62  Natal 2018-02-10   793.0     854     4    3172.0              4.0
# 52  Natal 2018-04-27   778.0     854     4    3112.0              4.0

# %%
df["Data"] = df["Data"].astype("int64")

# %%
df.dtypes
# Out:
# Cidade              object
# Data                 int64
# Vendas             float64
# LojaID               int64
# Qtde                 int64
# Receitas           float64
# Receitas/Vendas    float64
# dtype: object

# %%
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade                     object
# Data               datetime64[ns]
# Vendas                    float64
# LojaID                      int64
# Qtde                        int64
# Receitas                  float64
# Receitas/Vendas           float64
# dtype: object

# %%
df.groupby(df["Data"].dt.year)["Receitas"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receitas, dtype: float64

# %%
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  ...  Receitas  Receitas/Vendas  Ano_Venda
# 82    Salvador 2019-01-01  207.88  ...    207.88              1.0       2019
# 95    Salvador 2019-01-01    5.13  ...      5.13              1.0       2019
# 68   Fortaleza 2019-01-01   85.09  ...    510.54              6.0       2019
# 203      Natal 2019-01-02   37.75  ...     75.50              2.0       2019
# 80    Salvador 2019-01-01   40.24  ...     80.48              2.0       2019
#
# [5 rows x 8 columns]

# %%
df["mes_venda"], df["dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#       Cidade       Data  Vendas  ...  Ano_Venda  mes_venda  dia_venda
# 124    Natal 2019-01-02   44.82  ...       2019          1          2
# 114    Natal 2019-01-02   25.52  ...       2019          1          2
# 56   Aracaju 2018-01-01   41.90  ...       2018          1          1
# 108  Aracaju 2018-01-01   31.94  ...       2018          1          1
# 116   Recife 2019-03-02   79.10  ...       2019          3          2
#
# [5 rows x 10 columns]

# %%
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  ...  mes_venda  dia_venda  diferenca_dias
# 137      Natal 2019-01-02   51.66  ...          1          2        366 days
# 134  Fortaleza 2019-03-02  195.18  ...          3          2        425 days
# 121     Recife 2019-03-02   41.55  ...          3          2        425 days
# 43   Fortaleza 2019-01-01  191.52  ...          1          1        365 days
# 33      Recife 2019-01-01   32.33  ...          1          1        365 days
#
# [5 rows x 11 columns]

# %%
df["semestre_venda"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas  ...  dia_venda  diferenca_dias  semestre_venda
# 0    Salvador 2018-01-01   31.06  ...          1          0 days               1
# 77     Recife 2019-01-01  102.82  ...          1        365 days               1
# 12      Natal 2019-02-02  709.00  ...          2        397 days               1
# 198     Natal 2019-01-02   13.65  ...          2        366 days               1
# 174  Salvador 2019-01-02   35.30  ...          2        366 days               1
#
# [5 rows x 12 columns]

# %%
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19
# Out:
#         Cidade       Data  Vendas  ...  dia_venda  diferenca_dias  semestre_venda
# 108  Fortaleza 2019-03-02  152.89  ...          2        425 days               1
# 109  Fortaleza 2019-03-02   18.90  ...          2        425 days               1
# 110  Fortaleza 2019-03-02   51.98  ...          2        425 days               1
# 111  Fortaleza 2019-03-02    8.00  ...          2        425 days               1
# 112  Fortaleza 2019-03-02  133.59  ...          2        425 days               1
# ..         ...        ...     ...  ...        ...             ...             ...
# 137   Salvador 2019-03-02   51.66  ...          2        425 days               1
# 138   Salvador 2019-03-02  212.03  ...          2        425 days               1
# 139   Salvador 2019-03-02  169.01  ...          2        425 days               1
# 140   Salvador 2019-03-02   20.79  ...          2        425 days               1
# 141   Salvador 2019-03-02    9.08  ...          2        425 days               1
#
# [121 rows x 12 columns]

# %%
df["LojaID"].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 1523     29
# 852      29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df["LojaID"].value_counts(ascending=False).plot.bar()

# %%
df["LojaID"].value_counts().plot.barh();

# %%
df["LojaID"].value_counts(ascending=True).plot.barh();

# %%
df.groupby(df["Data"].dt.year)["Receitas"].sum().plot.pie();

# %%
df["Cidade"].value_counts()
# Out:
# Salvador     240
# Natal        240
# Recife       142
# Fortaleza    142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade")
plt.xlabel("Cidade")
plt.ylabel("Total vendas")
# Out:
# Text(0, 0.5, 'Total vendas')

# %%
df["Cidade"].value_counts().plot.bar(title="Total vendas por cidade", color="red")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas")
# Out:
# Text(0, 0.5, 'Total Vendas')

# %%
plt.style.use("ggplot")

# %%
df.groupby(df["mes_venda"])["Qtde"].sum().plot(title = "Total Produtos Vendidos x mes")
plt.xlabel["Mês"]
plt.ylabel("Total Produtos Vendidos");
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-4b2ad6550bf6> in <module>()
#       1 df.groupby(df["mes_venda"])["Qtde"].sum().plot(title = "Total Produtos Vendidos x mes")
# ----> 2 plt.xlabel["Mês"]
#       3 plt.ylabel("Total Produtos Vendidos");
#       4 plt.legend()
#
# TypeError: 'function' object is not subscriptable

# %%
df_2019 = df[df["Ano_Venda"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eb0c022ae792> in <module>()
# ----> 1 df_2019 = df[df["Ano_Venda"] == 2019]
#
# NameError: name 'df' is not defined
